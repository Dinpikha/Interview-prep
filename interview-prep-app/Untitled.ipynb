# %%
string='i am dipika am dipika am student'

# %%
import regex as re

# %%
mail="dipijgmail.com"

pattern=r"[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}"

# %%
match=re.search(pattern,mail)

# %%
match

# %%
ghub="https://github.com/Dinpikha"

# %%
ghubpatt=r"https://github\.com/[A-Za-z0-9+|%_.]+"

# %%
match=re.match(ghubpatt,ghub)
match
# Out:
# <regex.Match object; span=(0, 27), match='https://github.com/Dinpikha'>

# %%
y='I have 2 apples, 15 bananas, and 300 oranges 9189989090335.'
print(re.findall(r"[0-9]{10}",y))
# Out:
# ['9189989090']

# %%
ino='Python     React       FastAPI'

# %%
re.sub(r"[\s]+",' ',ino)
# Out:
# 'Python React FastAPI'

# %%
ino="""
Python

React


FastAPI
"""
re.sub(r"[\n]+",' ',ino)
# Out:
# ' Python React FastAPI '
